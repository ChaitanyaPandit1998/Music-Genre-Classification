# %%
import pandas as pd
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import librosa
import librosa.display
import IPython.display as ipd
import warnings
warnings.filterwarnings('ignore')

# %%
y,sr = librosa.load('../Data/genres_original/reggae/reggae.00036.wav')

# %%
print('y:',y,'\n') 
print('y shape:',y.shape,'\n')
print('Length of y:',len(y),'\n')
print('Type: ',type(y),'\n')
# Out:
# y: [0.02072144 0.04492188 0.05422974 ... 0.06912231 0.08303833 0.08572388]
#
# y shape: (661794,)
#
# Length of y: 661794
#
# Type:  <class 'numpy.ndarray'>

# %%
print('Sample Rate (KHz) :',sr,'\n')
print('Length of Audio File: ',y.shape[0]/sr,'seconds','\n')
# Out:
# Sample Rate (KHz) : 22050
#
# Length of Audio File:  30.013333333333332 seconds

# %%
audio_file,_ = librosa.effects.trim(y)

# %%
print('Audio File',audio_file,'\n')
print('Ret',_,'\n')
print('Shape of audio file: ',audio_file.shape,'\n')
# Out:
# Audio File [0.02072144 0.04492188 0.05422974 ... 0.06912231 0.08303833 0.08572388]
#
# Ret [     0 661794]
#
# Shape of audio file:  (661794,)

# %%
plt.figure(figsize=(16,6))
librosa.display.waveplot(y=audio_file,sr=sr,color = "#A300F9")
plt.title('Sound Waves in Reggae 36',fontsize=23)
# Out:
# Text(0.5, 1.0, 'Sound Waves in Reggae 36')

# %%
n_fft = 2048
hop_length = 512

D = np.abs(librosa.stft(y=audio_file,n_fft=n_fft,hop_length=hop_length))

# %%
print('D: ',D,'\n')
print('Shape of D: ',D.shape,'\n')
print('Length of D:',len(D),'\n')
print('Type: ',type(D),'\n')
# Out:
# D:  [[6.74255848e-01 3.33992273e-01 5.23666218e-02 ... 1.11128904e-01
#   8.50175858e-01 6.51748371e+00]
#  [6.31012261e-01 3.35162640e-01 9.75335613e-02 ... 1.23138517e-01
#   8.96887720e-01 6.86445236e+00]
#  [4.80873227e-01 3.10819119e-01 1.91733122e-01 ... 4.46834683e-01
#   1.22523260e+00 6.98825645e+00]
#  ...
#  [1.84022915e-02 9.40254144e-03 4.01545607e-04 ... 2.97801598e-05
#   1.94990390e-03 1.35544697e-02]
#  [1.85580198e-02 9.30057932e-03 2.28732955e-04 ... 5.36599691e-05
#   1.82967074e-03 1.33122467e-02]
#  [1.83994696e-02 9.11034737e-03 6.17524393e-06 ... 9.97001189e-06
#   1.67538458e-03 1.31017622e-02]]
#
# Shape of D:  (1025, 1293)
#
# Length of D: 1025
#
# Type:  <class 'numpy.ndarray'>

# %%
plt.figure(figsize = (16, 6))
plt.plot(D);
#To suppress the output, we append a semi-colon to the end of the last statement:

# %%
DB = librosa.amplitude_to_db(D,ref=np.max)

plt.figure(figsize=(16,6))
librosa.display.specshow(DB,x_axis='time',y_axis='log',cmap='cool',sr=sr,hop_length=hop_length)
plt.colorbar()

# %%
S = librosa.feature.melspectrogram(audio_file, sr=sr)
S_DB = librosa.amplitude_to_db(S, ref=np.max)
plt.figure(figsize = (16, 6))
librosa.display.specshow(S_DB, sr=sr, hop_length=hop_length, x_axis = 'time', y_axis = 'log',
                        cmap = 'cool');
plt.colorbar();
plt.title("Reggae Mel Spectrogram", fontsize = 23);

# %%
y_metal,sr_metal = librosa.load('../Data/genres_original/metal/metal.00036.wav')
y_metal,ret_metal = librosa.effects.trim(y_metal)

# %%
ret_metal
# Out:
# array([     0, 661504])

# %%
S_metal = librosa.feature.melspectrogram(y=y_metal,sr=sr_metal)
S_metalDB = librosa.amplitude_to_db(S_metal,ref = np.max)
plt.figure(figsize=(16,6))
librosa.display.specshow(S_metalDB,hop_length=hop_length,sr=sr_metal,cmap='cool',x_axis='time',y_axis='log')
plt.colorbar()
plt.title('Metal Mel Spectrogram',fontsize=23)
# Out:
# Text(0.5, 1.0, 'Metal Mel Spectrogram')

# %%
zero_crossings = librosa.zero_crossings(audio_file,pad=False)
zero_crossings_metal = librosa.zero_crossings(y_metal,pad=False)
print('Reggae Zero Crossings',sum(zero_crossings),'\n')
print('Metal Zero Crossings',sum(zero_crossings_metal),'\n')
print('Type :',type(zero_crossings))
# Out:
# Reggae Zero Crossings 39232
#
# Metal Zero Crossings 106295
#
# Type : <class 'numpy.ndarray'>

# %%
print(zero_crossings)
print(zero_crossings_metal)
# Out:
# [False False False ... False False False]
# [False False False ... False False False]

# %%
y_harm,y_per = librosa.effects.hpss(audio_file)
plt.figure(figsize=(16,6))
plt.plot(y_harm,color='#A300F9')
plt.plot(y_per,color='#FFB100')

# %%
y_harm_metal,y_per_metal = librosa.effects.hpss(y_metal)
plt.figure(figsize=(16,6))
plt.plot(y_harm_metal,color='#A300F9')
plt.plot(y_per_metal,color='#FFB100')

# %%
tempo,ret_beat_reggae = librosa.beat.beat_track(audio_file,sr=sr)
print(tempo)
# Out:
# 86.1328125

# %%
tempo_metal,ret_beat_metal = librosa.beat.beat_track(y_metal,sr=sr_metal)
print(tempo_metal)
# Out:
# 143.5546875

# %%
x = dataset_filtered[["label", "tempo"]]

f, ax = plt.subplots(figsize=(16, 9));
sns.boxplot(x = "label", y = "tempo", data = x, palette = 'husl');

plt.title('BPM Boxplot for Genres', fontsize = 25)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Genre", fontsize = 15)
plt.ylabel("BPM", fontsize = 15)
plt.savefig("BPM Boxplot.jpg")

# %%
# tempo, _ = librosa.beat.beat_track(y, sr = sr)
# tempo

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
#from xgboost import XGBClassifier

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

# %%
dataset = pd.read_csv('../Data/features_3_sec.csv')
dataset.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# 1              2010.051501            65671.875673  ...   64.748276
# 2              2084.565132            75124.921716  ...   67.336563
# 3              1960.039988            82913.639269  ...   47.739452
# 4              1948.503884            60204.020268  ...   30.336359
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -3.241280   36.488243     0.722209   38.099152    -5.050335   33.618073
# 1    -6.055294   40.677654     0.159015   51.264091    -2.837699   97.030830
# 2    -1.768610   28.348579     2.378768   45.717648    -1.938424   53.050835
# 3    -3.841155   28.337118     1.218588   34.770935    -3.580352   50.836224
# 4     0.664582   45.880913     1.689446   51.363583    -3.392489   26.738789
#
#    mfcc20_mean  mfcc20_var  label
# 0    -0.243027   43.771767  blues
# 1     5.784063   59.943081  blues
# 2     2.517375   33.105122  blues
# 3     3.630866   32.023678  blues
# 4     0.536961   29.146694  blues
#
# [5 rows x 60 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9990 entries, 0 to 9989
# Data columns (total 60 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   filename                 9990 non-null   object
#  1   length                   9990 non-null   int64
#  2   chroma_stft_mean         9990 non-null   float64
#  3   chroma_stft_var          9990 non-null   float64
#  4   rms_mean                 9990 non-null   float64
#  5   rms_var                  9990 non-null   float64
#  6   spectral_centroid_mean   9990 non-null   float64
#  7   spectral_centroid_var    9990 non-null   float64
#  8   spectral_bandwidth_mean  9990 non-null   float64
#  9   spectral_bandwidth_var   9990 non-null   float64
#  10  rolloff_mean             9990 non-null   float64
#  11  rolloff_var              9990 non-null   float64
#  12  zero_crossing_rate_mean  9990 non-null   float64
#  13  zero_crossing_rate_var   9990 non-null   float64
#  14  harmony_mean             9990 non-null   float64
#  15  harmony_var              9990 non-null   float64
#  16  perceptr_mean            9990 non-null   float64
#  17  perceptr_var             9990 non-null   float64
#  18  tempo                    9990 non-null   float64
#  19  mfcc1_mean               9990 non-null   float64
#  20  mfcc1_var                9990 non-null   float64
#  21  mfcc2_mean               9990 non-null   float64
#  22  mfcc2_var                9990 non-null   float64
#  23  mfcc3_mean               9990 non-null   float64
#  24  mfcc3_var                9990 non-null   float64
#  25  mfcc4_mean               9990 non-null   float64
#  26  mfcc4_var                9990 non-null   float64
#  27  mfcc5_mean               9990 non-null   float64
#  28  mfcc5_var                9990 non-null   float64
#  29  mfcc6_mean               9990 non-null   float64
#  30  mfcc6_var                9990 non-null   float64
#  31  mfcc7_mean               9990 non-null   float64
#  32  mfcc7_var                9990 non-null   float64
#  33  mfcc8_mean               9990 non-null   float64
#  34  mfcc8_var                9990 non-null   float64
#  35  mfcc9_mean               9990 non-null   float64
#  36  mfcc9_var                9990 non-null   float64
#  37  mfcc10_mean              9990 non-null   float64
#  38  mfcc10_var               9990 non-null   float64
#  39  mfcc11_mean              9990 non-null   float64
#  40  mfcc11_var               9990 non-null   float64
#  41  mfcc12_mean              9990 non-null   float64
#  42  mfcc12_var               9990 non-null   float64
#  43  mfcc13_mean              9990 non-null   float64
#  44  mfcc13_var               9990 non-null   float64
#  45  mfcc14_mean              9990 non-null   float64
#  46  mfcc14_var               9990 non-null   float64
#  47  mfcc15_mean              9990 non-null   float64
#  48  mfcc15_var               9990 non-null   float64
#  49  mfcc16_mean              9990 non-null   float64
#  50  mfcc16_var               9990 non-null   float64
#  51  mfcc17_mean              9990 non-null   float64
#  52  mfcc17_var               9990 non-null   float64
#  53  mfcc18_mean              9990 non-null   float64
#  54  mfcc18_var               9990 non-null   float64
#  55  mfcc19_mean              9990 non-null   float64
#  56  mfcc19_var               9990 non-null   float64
#  57  mfcc20_mean              9990 non-null   float64
#  58  mfcc20_var               9990 non-null   float64
#  59  label                    9990 non-null   object
# dtypes: float64(57), int64(1), object(2)
# memory usage: 4.6+ MB

# %%
dataset['label'].unique()

# %%
dataset['label'].nunique()

# %%
dataset.isnull().sum()

# %%
num_cols = dataset._get_numeric_data().columns
print(num_cols)
print('-----------------***********************-------------------------------')
print('Total',len(num_cols))

# %%
print(set(dataset.columns)-set(num_cols))

# %%
dataset_filtered = dataset.iloc[:,1:]
dataset_filtered.head()
# Out:
#    length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0   66149          0.335406         0.091048  0.130405  0.003521
# 1   66149          0.343065         0.086147  0.112699  0.001450
# 2   66149          0.346815         0.092243  0.132003  0.004620
# 3   66149          0.363639         0.086856  0.132565  0.002448
# 4   66149          0.335579         0.088129  0.143289  0.001701
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1773.065032          167541.630869              1972.744388
# 1             1816.693777           90525.690866              2010.051501
# 2             1788.539719          111407.437613              2084.565132
# 3             1655.289045          111952.284517              1960.039988
# 4             1630.656199           79667.267654              1948.503884
#
#    spectral_bandwidth_var  rolloff_mean  ...  mfcc16_var  mfcc17_mean  \
# 0           117335.771563   3714.560359  ...   39.687145    -3.241280
# 1            65671.875673   3869.682242  ...   64.748276    -6.055294
# 2            75124.921716   3997.639160  ...   67.336563    -1.768610
# 3            82913.639269   3568.300218  ...   47.739452    -3.841155
# 4            60204.020268   3469.992864  ...   30.336359     0.664582
#
#    mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  \
# 0   36.488243     0.722209   38.099152    -5.050335   33.618073    -0.243027
# 1   40.677654     0.159015   51.264091    -2.837699   97.030830     5.784063
# 2   28.348579     2.378768   45.717648    -1.938424   53.050835     2.517375
# 3   28.337118     1.218588   34.770935    -3.580352   50.836224     3.630866
# 4   45.880913     1.689446   51.363583    -3.392489   26.738789     0.536961
#
#    mfcc20_var  label
# 0   43.771767  blues
# 1   59.943081  blues
# 2   33.105122  blues
# 3   32.023678  blues
# 4   29.146694  blues
#
# [5 rows x 59 columns]

# %%
dataset_filtered['label'].value_counts()
# Out:
# metal        1000
# blues        1000
# reggae       1000
# jazz         1000
# pop          1000
# disco         999
# classical     998
# hiphop        998
# rock          998
# country       997
# Name: label, dtype: int64

# %%
temp_list = dataset_filtered['label'].value_counts()
count_list = []
for i in range(len(temp_list)):
    count_list.append(temp_list[i])

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=pd.Series(dataset_filtered['label'].value_counts()).index, y=pd.Series(count_list), palette ='hsv')
plt.xticks(rotation= 45)
plt.xlabel('Labels')
plt.ylabel('Label Count')
plt.title('Labels And Their Counts')
# Out:
# Text(0.5, 1.0, 'Labels And Their Counts')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data=dataset_filtered.corr(),cmap='hsv')
# Out:
# <AxesSubplot:>

# %%
c = dataset_filtered.corr()
s = c.unstack()
s = s.dropna()
so = s.sort_values(kind='quicksort')

# %%
top_corr = []
top_corr_index = []
for i in range(len(so)):
    if so[i] > 0.9 and so[i] < 1.0:
        top_corr.append(so[i])
        top_corr_index.append(i)
print(top_corr)
print("*----------------------------------------------------------------------------------------------*")
print(top_corr_index)
# Out:
# [0.9510001983017642, 0.9510001983017642, 0.9743599625424502, 0.9743599625424502]
# *----------------------------------------------------------------------------------------------*
# [3188, 3189, 3190, 3191]

# %%
print(f'Most Correlated - \n{so[3188:3192]}')
# Out:
# Most Correlated -
# spectral_bandwidth_mean  rolloff_mean               0.95100
# rolloff_mean             spectral_bandwidth_mean    0.95100
#                          spectral_centroid_mean     0.97436
# spectral_centroid_mean   rolloff_mean               0.97436
# dtype: float64

# %%
dataset_filtered.drop('rolloff_mean',axis = 1,inplace = True)
dataset_filtered.drop('spectral_bandwidth_mean',axis = 1,inplace = True)
dataset_filtered.drop('spectral_centroid_mean',axis = 1,inplace = True)

# %%
y = dataset_filtered['label'].values
X = dataset_filtered.drop('label',axis=1).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
def model_assess(model, title = "Default"):
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)
    #print(confusion_matrix(y_test, preds))
    print('Accuracy', title, ':', round(accuracy_score(y_test, preds), 5), '\n')

# %%
# Naive Bayes
nb = GaussianNB()
model_assess(nb, "Naive Bayes")

# Stochastic Gradient Descent
sgd = SGDClassifier(max_iter=5000, random_state=0)
model_assess(sgd, "Stochastic Gradient Descent")

# KNN
knn = KNeighborsClassifier(n_neighbors=19)
model_assess(knn, "KNN")

# Decission trees
tree = DecisionTreeClassifier()
model_assess(tree, "Decission trees")

# Random Forest
rforest = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
model_assess(rforest, "Random Forest")

# Support Vector Machine
svm = SVC(decision_function_shape="ovo")
model_assess(svm, "Support Vector Machine")

# Logistic Regression
lg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
model_assess(lg, "Logistic Regression")

# Cross Gradient Booster
# xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
# model_assess(xgb, "Cross Gradient Booster")
# Out:
# Accuracy Naive Bayes : 0.53153
#
# Accuracy Stochastic Gradient Descent : 0.65999
#
# Accuracy KNN : 0.7968
#
# Accuracy Decission trees : 0.64464
#
# Accuracy Random Forest : 0.81715
#
# Accuracy Support Vector Machine : 0.85152
#
# Accuracy Logistic Regression : 0.71271

# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=1024, activation='relu'))
ann.add(Dropout(0.2))

ann.add(tf.keras.layers.Dense(units=512, activation='relu'))
ann.add(Dropout(0.2))

ann.add(tf.keras.layers.Dense(units=256, activation='relu'))
ann.add(Dropout(0.2))

ann.add(tf.keras.layers.Dense(units=128, activation='relu'))
ann.add(Dropout(0.2))

ann.add(tf.keras.layers.Dense(units=64, activation='relu'))
ann.add(Dropout(0.2))

ann.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %%
ann.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
# Adam combines the best properties of the AdaGrad and RMSProp algorithms to provide an optimization algorithm 
# that can handle sparse gradients on noisy problems.

# %%
X_train_scaled.shape
# Out:
# (6993, 55)

# %%
# len(X_train_scaled) ---> 6993
# len(X_train_scaled[0]) --> 58

# %%
y_train
# Out:
# array(['disco', 'reggae', 'hiphop', ..., 'reggae', 'classical',
#        'classical'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
y = labelencoder.fit_transform(y)
print(y)
# Out:
# [0 0 0 ... 9 9 9]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
history = ann.fit(X_train_scaled, y_train, batch_size = 32,validation_data=(X_test_scaled,y_test),epochs = 100)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0410 - accuracy: 0.9906 - val_loss: 0.5312 - val_accuracy: 0.9132
# Epoch 2/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0447 - accuracy: 0.9884 - val_loss: 0.5388 - val_accuracy: 0.9079
# Epoch 3/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0666 - accuracy: 0.9860 - val_loss: 0.4783 - val_accuracy: 0.9086
# Epoch 4/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0362 - accuracy: 0.9900 - val_loss: 0.5468 - val_accuracy: 0.9159
# Epoch 5/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0498 - accuracy: 0.9874 - val_loss: 0.4884 - val_accuracy: 0.9166
# Epoch 6/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0522 - accuracy: 0.9891 - val_loss: 0.4764 - val_accuracy: 0.9196
# Epoch 7/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0308 - accuracy: 0.9939 - val_loss: 0.5052 - val_accuracy: 0.9196
# Epoch 8/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0543 - accuracy: 0.9896 - val_loss: 0.4504 - val_accuracy: 0.9183
# Epoch 9/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0422 - accuracy: 0.9901 - val_loss: 0.4503 - val_accuracy: 0.9162
# Epoch 10/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0216 - accuracy: 0.9937 - val_loss: 0.5483 - val_accuracy: 0.9156
# Epoch 11/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0465 - accuracy: 0.9891 - val_loss: 0.4855 - val_accuracy: 0.9226
# Epoch 12/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0411 - accuracy: 0.9904 - val_loss: 0.4484 - val_accuracy: 0.9223
# Epoch 13/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0344 - accuracy: 0.9910 - val_loss: 0.5847 - val_accuracy: 0.9162
# Epoch 14/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0431 - accuracy: 0.9894 - val_loss: 0.5260 - val_accuracy: 0.9166
# Epoch 15/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0400 - accuracy: 0.9898 - val_loss: 0.5326 - val_accuracy: 0.9126
# Epoch 16/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0524 - accuracy: 0.9884 - val_loss: 0.5476 - val_accuracy: 0.9112
# Epoch 17/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0450 - accuracy: 0.9894 - val_loss: 0.4714 - val_accuracy: 0.9186
# Epoch 18/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.5445 - val_accuracy: 0.9219
# Epoch 19/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0225 - accuracy: 0.9933 - val_loss: 0.5426 - val_accuracy: 0.9213
# Epoch 20/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0261 - accuracy: 0.9943 - val_loss: 0.5345 - val_accuracy: 0.9203
# Epoch 21/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0491 - accuracy: 0.9901 - val_loss: 0.5308 - val_accuracy: 0.9203
# Epoch 22/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0561 - accuracy: 0.9864 - val_loss: 0.4728 - val_accuracy: 0.9169
# Epoch 23/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0391 - accuracy: 0.9903 - val_loss: 0.5068 - val_accuracy: 0.9146
# Epoch 24/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0446 - accuracy: 0.9876 - val_loss: 0.4583 - val_accuracy: 0.9173
# Epoch 25/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0283 - accuracy: 0.9927 - val_loss: 0.5761 - val_accuracy: 0.9179
# Epoch 26/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0501 - accuracy: 0.9891 - val_loss: 0.4558 - val_accuracy: 0.9179
# Epoch 27/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0292 - accuracy: 0.9920 - val_loss: 0.4949 - val_accuracy: 0.9132
# Epoch 28/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0434 - accuracy: 0.9893 - val_loss: 0.4888 - val_accuracy: 0.9156
# Epoch 29/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0342 - accuracy: 0.9933 - val_loss: 0.5957 - val_accuracy: 0.9102
# Epoch 30/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0487 - accuracy: 0.9893 - val_loss: 0.4750 - val_accuracy: 0.9173
# Epoch 31/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0344 - accuracy: 0.9910 - val_loss: 0.6069 - val_accuracy: 0.9169
# Epoch 32/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0355 - accuracy: 0.9911 - val_loss: 0.6164 - val_accuracy: 0.9096
# Epoch 33/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0296 - accuracy: 0.9918 - val_loss: 0.5961 - val_accuracy: 0.9179
# Epoch 34/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0457 - accuracy: 0.9880 - val_loss: 0.5389 - val_accuracy: 0.9186
# Epoch 35/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0344 - accuracy: 0.9910 - val_loss: 0.5782 - val_accuracy: 0.9156
# Epoch 36/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0527 - accuracy: 0.9880 - val_loss: 0.5452 - val_accuracy: 0.9229
# Epoch 37/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0443 - accuracy: 0.9898 - val_loss: 0.4618 - val_accuracy: 0.9249
# Epoch 38/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0260 - accuracy: 0.9923 - val_loss: 0.5788 - val_accuracy: 0.9099
# Epoch 39/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0258 - accuracy: 0.9933 - val_loss: 0.5213 - val_accuracy: 0.9209
# Epoch 40/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0576 - accuracy: 0.9896 - val_loss: 0.4657 - val_accuracy: 0.9229
# Epoch 41/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0282 - accuracy: 0.9926 - val_loss: 0.5417 - val_accuracy: 0.9176
# Epoch 42/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0324 - accuracy: 0.9931 - val_loss: 0.5264 - val_accuracy: 0.9213
# Epoch 43/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0313 - accuracy: 0.9930 - val_loss: 0.5098 - val_accuracy: 0.9216
# Epoch 44/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0327 - accuracy: 0.9910 - val_loss: 0.5550 - val_accuracy: 0.9186
# Epoch 45/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0287 - accuracy: 0.9929 - val_loss: 0.5872 - val_accuracy: 0.9213
# Epoch 46/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0404 - accuracy: 0.9898 - val_loss: 0.6120 - val_accuracy: 0.9129
# Epoch 47/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0304 - accuracy: 0.9921 - val_loss: 0.6353 - val_accuracy: 0.9162
# Epoch 48/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0489 - accuracy: 0.9911 - val_loss: 0.4604 - val_accuracy: 0.9229
# Epoch 49/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0314 - accuracy: 0.9951 - val_loss: 0.4927 - val_accuracy: 0.9246
# Epoch 50/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0356 - accuracy: 0.9923 - val_loss: 0.6367 - val_accuracy: 0.9196
# Epoch 51/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0386 - accuracy: 0.9916 - val_loss: 0.5733 - val_accuracy: 0.9223
# Epoch 52/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0288 - accuracy: 0.9929 - val_loss: 0.7036 - val_accuracy: 0.9146
# Epoch 53/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0513 - accuracy: 0.9887 - val_loss: 0.4804 - val_accuracy: 0.9239
# Epoch 54/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0221 - accuracy: 0.9947 - val_loss: 0.5288 - val_accuracy: 0.9259
# Epoch 55/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0236 - accuracy: 0.9943 - val_loss: 0.5452 - val_accuracy: 0.9283
# Epoch 56/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0218 - accuracy: 0.9956 - val_loss: 0.5749 - val_accuracy: 0.9229
# Epoch 57/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0340 - accuracy: 0.9924 - val_loss: 0.6187 - val_accuracy: 0.9193
# Epoch 58/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0432 - accuracy: 0.9900 - val_loss: 0.5769 - val_accuracy: 0.9196
# Epoch 59/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0281 - accuracy: 0.9917 - val_loss: 0.6100 - val_accuracy: 0.9226
# Epoch 60/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0349 - accuracy: 0.9927 - val_loss: 0.5326 - val_accuracy: 0.9216
# Epoch 61/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0402 - accuracy: 0.9917 - val_loss: 0.4933 - val_accuracy: 0.9179
# Epoch 62/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0450 - accuracy: 0.9923 - val_loss: 0.4479 - val_accuracy: 0.9223
# Epoch 63/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0283 - accuracy: 0.9933 - val_loss: 0.4731 - val_accuracy: 0.9279
# Epoch 64/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0558 - accuracy: 0.9890 - val_loss: 0.5493 - val_accuracy: 0.9112
# Epoch 65/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0334 - accuracy: 0.9910 - val_loss: 0.5001 - val_accuracy: 0.9189
# Epoch 66/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0355 - accuracy: 0.9917 - val_loss: 0.5099 - val_accuracy: 0.9236
# Epoch 67/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0315 - accuracy: 0.9910 - val_loss: 0.4785 - val_accuracy: 0.9259
# Epoch 68/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0206 - accuracy: 0.9953 - val_loss: 0.5554 - val_accuracy: 0.9219
# Epoch 69/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0431 - accuracy: 0.9906 - val_loss: 0.4288 - val_accuracy: 0.9229
# Epoch 70/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0192 - accuracy: 0.9953 - val_loss: 0.4658 - val_accuracy: 0.9243
# Epoch 71/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0310 - accuracy: 0.9936 - val_loss: 0.7357 - val_accuracy: 0.9022
# Epoch 72/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0573 - accuracy: 0.9880 - val_loss: 0.5322 - val_accuracy: 0.9149
# Epoch 73/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0385 - accuracy: 0.9923 - val_loss: 0.5523 - val_accuracy: 0.9173
# Epoch 74/100
# 219/219 [==============================] - 3s 14ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 0.5553 - val_accuracy: 0.9196
# Epoch 75/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0310 - accuracy: 0.9930 - val_loss: 0.5263 - val_accuracy: 0.9183
# Epoch 76/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0236 - accuracy: 0.9947 - val_loss: 0.4852 - val_accuracy: 0.9293
# Epoch 77/100
# 219/219 [==============================] - 3s 11ms/step - loss: 0.0439 - accuracy: 0.9894 - val_loss: 0.5367 - val_accuracy: 0.9243
# Epoch 78/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0391 - accuracy: 0.9910 - val_loss: 0.4794 - val_accuracy: 0.9286
# Epoch 79/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0408 - accuracy: 0.9904 - val_loss: 0.4113 - val_accuracy: 0.9263
# Epoch 80/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0282 - accuracy: 0.9933 - val_loss: 0.4646 - val_accuracy: 0.9279
# Epoch 81/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0445 - accuracy: 0.9936 - val_loss: 0.5820 - val_accuracy: 0.9052
# Epoch 82/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0397 - accuracy: 0.9927 - val_loss: 0.5626 - val_accuracy: 0.9189
# Epoch 83/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0258 - accuracy: 0.9936 - val_loss: 0.5631 - val_accuracy: 0.9129
# Epoch 84/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0249 - accuracy: 0.9933 - val_loss: 0.5701 - val_accuracy: 0.9223
# Epoch 85/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0293 - accuracy: 0.9917 - val_loss: 0.5388 - val_accuracy: 0.9223
# Epoch 86/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0352 - accuracy: 0.9914 - val_loss: 0.4903 - val_accuracy: 0.9289
# Epoch 87/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0393 - accuracy: 0.9917 - val_loss: 0.5145 - val_accuracy: 0.9239
# Epoch 88/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0293 - accuracy: 0.9923 - val_loss: 0.6088 - val_accuracy: 0.9223
# Epoch 89/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0165 - accuracy: 0.9959 - val_loss: 0.6099 - val_accuracy: 0.9259
# Epoch 90/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0237 - accuracy: 0.9934 - val_loss: 0.5830 - val_accuracy: 0.9233
# Epoch 91/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0327 - accuracy: 0.9927 - val_loss: 0.5950 - val_accuracy: 0.9193
# Epoch 92/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0216 - accuracy: 0.9944 - val_loss: 0.6115 - val_accuracy: 0.9226
# Epoch 93/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0286 - accuracy: 0.9927 - val_loss: 0.5525 - val_accuracy: 0.9209
# Epoch 94/100
# 219/219 [==============================] - 3s 13ms/step - loss: 0.0230 - accuracy: 0.9943 - val_loss: 0.6414 - val_accuracy: 0.9216
# Epoch 95/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0536 - accuracy: 0.9890 - val_loss: 0.5625 - val_accuracy: 0.9162
# Epoch 96/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0504 - accuracy: 0.9891 - val_loss: 0.5227 - val_accuracy: 0.9162
# Epoch 97/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0255 - accuracy: 0.9918 - val_loss: 0.5171 - val_accuracy: 0.9226
# Epoch 98/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0240 - accuracy: 0.9954 - val_loss: 0.5770 - val_accuracy: 0.9239
# Epoch 99/100
# 219/219 [==============================] - 3s 12ms/step - loss: 0.0490 - accuracy: 0.9898 - val_loss: 0.5064 - val_accuracy: 0.9213
# Epoch 100/100
# 219/219 [==============================] - 2s 11ms/step - loss: 0.0191 - accuracy: 0.9949 - val_loss: 0.5576 - val_accuracy: 0.9223

# %%
train_loss, train_acc = ann.evaluate(X_train_scaled, y_train, batch_size=32)
test_loss, test_acc  = ann.evaluate(X_test_scaled, y_test, batch_size=32)
# Out:
# 219/219 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9996
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5576 - accuracy: 0.9223

# %%
print('Train Loss = ',train_loss,'\nTrain Accuracy = ',train_acc * 100)
print('******************************')
print('Test Loss = ',test_loss,'\nTest Accuracy = ',test_acc * 100)
# Out:
# Train Loss =  0.0012781770201399922
# Train Accuracy =  99.95710253715515
# ******************************
# Test Loss =  0.5576004385948181
# Test Accuracy =  92.22555756568909

# %%
# list all data in history
plt.figure(figsize=(15,10))
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.figure(figsize=(15,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
algos = ['Naive Bayes','Stochastic Gradient Descent','KNN','Decission trees','Random Forest','Support Vector Machine','Logistic Regression','Neural Network']
values = [0.53153,0.65999,0.7968,0.64464, 0.81715,0.85152,0.71271,0.9223]
data={'Algorithms':algos,'Accuracy':values}
res = pd.DataFrame(data=data)
plt.figure(figsize=(15,10))
sns.barplot(data = res,x=res['Accuracy'],y=res['Algorithms'])
# Out:
# <AxesSubplot:xlabel='Accuracy', ylabel='Algorithms'>
